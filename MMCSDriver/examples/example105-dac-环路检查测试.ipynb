# %%
'''
检查fpga代码版本
'''
from mmcs_driver.MmcsDriver_mod import MmcsDriver_cls as MmcsDriver
import numpy as np
import datetime
import time


#打开驱动，连结所有机箱
driver = MmcsDriver(box_ip_dict={"box1":'192.168.4.8'})
# driver = MmcsDriver(box_ip_dict={'box1':'192.168.4.7','box2':"192.168.4.8",'box3':'192.168.4.9'})

# driver.bp_pcie_power_restart(name='bp_box2',pcie_num_list=[6])
driver.sys_reset_whole_system()

#记录运行时间
start_time = datetime.datetime.now()

i=0
while True:
    if i%10==0:
        print(i)
    #random data
    len = np.random.randint(1,100_000)
    data = np.random.randint(0,2**32-1,len,dtype=np.uint32)
    # data = np.array([101,102,103,104,105,106,107,108,109,110],dtype=np.uint32)
    data_back = driver.da_data_loop(name='da_box1pcie8ch12',data=data)
    #wait 0.5s
    # time.sleep(0.1)
    if data.size != data_back.size:
        print('data.size!=data_back.size')
        print(data.size)
        print(data_back.size)
        #记录时间
        end_time = datetime.datetime.now()
        print('time:',end_time-start_time)
        print("end_time:",end_time)
        break
    if (data != data_back).any():
        print('data!=data_back')
        print(data)
        print(data_back)
        #记录时间
        end_time = datetime.datetime.now()
        print('time:',end_time-start_time)
        print("end_time:",end_time)
        break
    i+=1
print('done')
# Out:
# box1插槽8：DAC
# box1插槽9：ADC
# sys_connect_box()找到如下可用对象:
# DAC板卡通道: dict_keys(['da_box1pcie8ch12', 'da_box1pcie8ch34'])
# ADC板卡通道: dict_keys(['ad_box1pcie9ch12', 'ad_box1pcie9ch34'])
# 开始初始化DAC芯片...
# DAC正在初始化....
# DAC初始化完成: 总数：1，成功：1，失败：0，未响应：0
# 详细DAC初始化结果如下: T代表成功, F代表失败
#             PCIE1 PCIE2 PCIE3 PCIE4 PCIE5 PCIE6 PCIE7 PCIE8 PCIE9 PCIE10  \
# IP
# 192.168.4.8                                               T
#
#             PCIE11 PCIE12 PCIE13 PCIE14
# IP
# 192.168.4.8
# ADC板卡ad_box1pcie9ch12已经初始化完成
# ADC板卡ad_box1pcie9ch34已经初始化完成
# 背板bp_box1已经初始化完成，通讯模块与level2 trigger ram已经清空
# 开始清空所有DAC板卡的波形内存...
# 清空DAC板卡da_box1pcie8ch12的波形内存...
# 清空DAC板卡da_box1pcie8ch34的波形内存...
# 所有DAC板卡波形内存已经清空
# 0
# 10
# data.size!=data_back.size
# 88646
# 88649
# time: 0:00:00.144999
# end_time: 2024-10-17 10:40:57.019280
# done

# %%
data.shape
# Out:
# (88646,)

# %%
data_back.shape
# Out:
# (88649,)
